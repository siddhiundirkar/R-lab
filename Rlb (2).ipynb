# %%
 
wine <- read.csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv",header=T, sep=";")
wine
# Out:
#      fixed.acidity volatile.acidity citric.acid residual.sugar chlorides
# 1    7.0           0.27             0.36        20.70          0.045
# 2    6.3           0.30             0.34         1.60          0.049
# 3    8.1           0.28             0.40         6.90          0.050
# 4    7.2           0.23             0.32         8.50          0.058
# 5    7.2           0.23             0.32         8.50          0.058
# 6    8.1           0.28             0.40         6.90          0.050
# 7    6.2           0.32             0.16         7.00          0.045
# 8    7.0           0.27             0.36        20.70          0.045
# 9    6.3           0.30             0.34         1.60          0.049
# 10   8.1           0.22             0.43         1.50          0.044
# 11   8.1           0.27             0.41         1.45          0.033
# 12   8.6           0.23             0.40         4.20          0.035
# 13   7.9           0.18             0.37         1.20          0.040
# ...

# %% [markdown]
# Task Number 1:

# %%
# summary of entire data
summary(wine)
# Out:
#  fixed.acidity    volatile.acidity  citric.acid     residual.sugar
#  Min.   : 3.800   Min.   :0.0800   Min.   :0.0000   Min.   : 0.600
#  1st Qu.: 6.300   1st Qu.:0.2100   1st Qu.:0.2700   1st Qu.: 1.700
#  Median : 6.800   Median :0.2600   Median :0.3200   Median : 5.200
#  Mean   : 6.855   Mean   :0.2782   Mean   :0.3342   Mean   : 6.391
#  3rd Qu.: 7.300   3rd Qu.:0.3200   3rd Qu.:0.3900   3rd Qu.: 9.900
#  Max.   :14.200   Max.   :1.1000   Max.   :1.6600   Max.   :65.800
#    chlorides       free.sulfur.dioxide total.sulfur.dioxide    density
#  Min.   :0.00900   Min.   :  2.00      Min.   :  9.0        Min.   :0.9871
#  1st Qu.:0.03600   1st Qu.: 23.00      1st Qu.:108.0        1st Qu.:0.9917
#  Median :0.04300   Median : 34.00      Median :134.0        Median :0.9937
#  Mean   :0.04577   Mean   : 35.31      Mean   :138.4        Mean   :0.9940
#  3rd Qu.:0.05000   3rd Qu.: 46.00      3rd Qu.:167.0        3rd Qu.:0.9961
# ...

# %%
# class holding that data
class(wine)
# Out:
# [1] "data.frame"

# %%
# obtain 5 statistical summary for all attributes
paste('Min.Lower.Medain.Upper.Max')
fivenum(wine$fixed.acidity)
fivenum(wine$volatile.acidity)
fivenum(wine$citric.acid)
fivenum(wine$residual.sugar)
fivenum(wine$chlorides)
fivenum(wine$free.sulfur.dioxide)
fivenum(wine$total.sulfur.dioxide)
fivenum(wine$density)
fivenum(wine$pH)
fivenum(wine$sulphates)
fivenum(wine$alcohol)
fivenum(wine$quality)
# Out:
# [1] "Min.Lower.Medain.Upper.Max"
# [1]  3.8  6.3  6.8  7.3 14.2
# [1] 0.08 0.21 0.26 0.32 1.10
# [1] 0.00 0.27 0.32 0.39 1.66
# [1]  0.6  1.7  5.2  9.9 65.8
# [1] 0.009 0.036 0.043 0.050 0.346
# [1]   2  23  34  46 289
# [1]   9 108 134 167 440
# [1] 0.98711 0.99172 0.99374 0.99610 1.03898
# [1] 2.72 3.09 3.18 3.28 3.82
# [1] 0.22 0.41 0.47 0.55 1.08
# [1]  8.0  9.5 10.4 11.4 14.2
# [1] 3 5 6 6 9

# %%
# To find subset of 2 attributes
sub_wine <- wine[c(100:200),c(3:4)]
sub_wine
# Out:
#     citric.acid residual.sugar
# 100 0.66        15.90
# 101 0.37        13.50
# 102 0.32         9.60
# 103 0.24        12.10
# 104 0.40        18.90
# 105 0.37        13.50
# 106 0.32        14.40
# 107 0.32         9.60
# 108 0.35        16.50
# 109 0.35        16.50
# 110 0.28         1.30
# 111 0.54         8.50
# 112 0.46        18.75
# 113 0.50        13.30
# 114 0.34         9.20
# 115 0.34         9.20
# 116 0.00         1.50
# 117 0.24         3.30
# 118 0.40         1.70
# 119 0.50        13.30
# 120 0.48        13.30
# 121 0.04         5.70
# 122 0.32        12.20
# 123 0.31         6.85
# 124 0.28         5.00
# 125 0.47         1.60
# 126 0.36         1.10
# 127 0.23         7.00
# 128 0.32         7.60
# 129 0.56         2.80
# ⋮   ⋮           ⋮
# 171 0.46         1.50
# 172 0.45         1.50
# 173 0.37         0.80
# 174 0.43         4.55
# 175 0.31        17.70
# 176 0.40         7.50
# 177 0.47         5.10
# 178 0.30        12.90
# 179 0.07         1.20
# ...

# %%
# R function to find sample tuple
install.packages("dplyr")
library("dplyr")
data_s <- sample_n(wine[4:5],4)
data_s
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#   residual.sugar chlorides
# 1 1.4            0.030
# 2 8.4            0.031
# 3 1.7            0.034
# 4 1.6            0.039

# %% [markdown]
# Task Number 2:

# %%
tar <- wine$target
sapply(wine, function(tar) sum(is.na(tar)))
# Out:
#        fixed.acidity     volatile.acidity          citric.acid
#                    0                    0                    0
#       residual.sugar            chlorides  free.sulfur.dioxide
#                    0                    0                    0
# total.sulfur.dioxide              density                   pH
#                    0                    0                    0
#            sulphates              alcohol              quality
#                    0                    0                    0

# %%
# b. select colum with more than 10% values missing for deletation. Create new copy of dataset
# that has one less column call it sample_data_1less.

## Remove columns with more than 10% NA
dataless1 <-wine[, which(colMeans(!is.na(wine)) > 0.1)]
dataless1
# Out:
#      fixed.acidity volatile.acidity citric.acid residual.sugar chlorides
# 1    7.0           0.27             0.36        20.70          0.045
# 2    6.3           0.30             0.34         1.60          0.049
# 3    8.1           0.28             0.40         6.90          0.050
# 4    7.2           0.23             0.32         8.50          0.058
# 5    7.2           0.23             0.32         8.50          0.058
# 6    8.1           0.28             0.40         6.90          0.050
# 7    6.2           0.32             0.16         7.00          0.045
# 8    7.0           0.27             0.36        20.70          0.045
# 9    6.3           0.30             0.34         1.60          0.049
# 10   8.1           0.22             0.43         1.50          0.044
# 11   8.1           0.27             0.41         1.45          0.033
# 12   8.6           0.23             0.40         4.20          0.035
# 13   7.9           0.18             0.37         1.20          0.040
# ...

# %%
# c. Find 5 point summary of all remaining columns with numric attributes
summary(dataless1)
# Out:
#  fixed.acidity    volatile.acidity  citric.acid     residual.sugar
#  Min.   : 3.800   Min.   :0.0800   Min.   :0.0000   Min.   : 0.600
#  1st Qu.: 6.300   1st Qu.:0.2100   1st Qu.:0.2700   1st Qu.: 1.700
#  Median : 6.800   Median :0.2600   Median :0.3200   Median : 5.200
#  Mean   : 6.855   Mean   :0.2782   Mean   :0.3342   Mean   : 6.391
#  3rd Qu.: 7.300   3rd Qu.:0.3200   3rd Qu.:0.3900   3rd Qu.: 9.900
#  Max.   :14.200   Max.   :1.1000   Max.   :1.6600   Max.   :65.800
#    chlorides       free.sulfur.dioxide total.sulfur.dioxide    density
#  Min.   :0.00900   Min.   :  2.00      Min.   :  9.0        Min.   :0.9871
#  1st Qu.:0.03600   1st Qu.: 23.00      1st Qu.:108.0        1st Qu.:0.9917
#  Median :0.04300   Median : 34.00      Median :134.0        Median :0.9937
#  Mean   :0.04577   Mean   : 35.31      Mean   :138.4        Mean   :0.9940
#  3rd Qu.:0.05000   3rd Qu.: 46.00      3rd Qu.:167.0        3rd Qu.:0.9961
# ...

# %%
# d. For attribute having maximum spread delete all tuples that have value less than the mean of the
# attribute selected. Count the number of tuples reamining in the sampled dataset.

m <- mean(wine$fixed.acidity, na.rm = FALSE)
m

df2 <- subset(wine, wine$fixed.acidity< m)
summary(df2$fixed.acidity)
print('Rows before row deletion: ')
nrow(wine)
print('Rows before row deletion: ')
nrow(df2)
# Out:
# [1] 6.854788
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   3.800   6.000   6.400   6.255   6.600   6.800
# [1] "Rows before row deletion: "
# [1] 4898
# [1] "Rows before row deletion: "
# [1] 2635

# %%
# a. print the 5 point statistical summary for any 2 numeric attributes from your data set
fivenum(wine$fixed.acidity) 
fivenum(wine$residual.sugar)
# Out:
# [1]  3.8  6.3  6.8  7.3 14.2
# [1]  0.6  1.7  5.2  9.9 65.8

# %% [markdown]
# Task Number 3:

# %%
# a. print the 5 point statistical summary for any 2 numeric attributes from your data set
fivenum(wine$fixed.acidity) 
fivenum(wine$density)
# Out:
# [1]  3.8  6.3  6.8  7.3 14.2
# [1] 0.98711 0.99172 0.99374 0.99610 1.03898

# %%
# b. select 2 atributes have closest mean value and draw a scatter plot with proper x and labelsloi
# ntt and title (for plotting you must use R library functions or gnuplot and not matplotlib )
means<- colMeans(wine[sapply(wine, is.numeric)] )
means

library(ggplot2)

volatile.acidity<-wine$volatile.acidity
critic.acid<-wine$critic.acid
plot(wine$volatile.acidity , wine$critic.acid , main = "Scatterplot" , xlab = "volatile.acidity" , ylab = "critic.acid" , las = 1 , xlim = c(0,2) , col = 2 )
# Out:
#        fixed.acidity     volatile.acidity          citric.acid
#           6.85478767           0.27824112           0.33419151
#       residual.sugar            chlorides  free.sulfur.dioxide
#           6.39141486           0.04577236          35.30808493
# total.sulfur.dioxide              density                   pH
#         138.36065741           0.99402738           3.18826664
#            sulphates              alcohol              quality
#           0.48984688          10.51426705           5.87790935
# Plot with title “Scatterplot”

# %%
# e. Write a R function to plot histogram of some specific input attribute for any data set provided
new.function <- function(volatile.acidity) {
   hist(volatile.acidity)
}

new.function(volatile.acidity)
# Out:
# Plot with title “Histogram of volatile.acidity”

# %%
cor(critic.acid,density, method = c("pearson", "kendall", "spearman"))
# Out:
# Error in cor(critic.acid, density, method = c("pearson", "kendall", "spearman")): 'x' must be numeric
# Traceback:
#
# 1. cor(critic.acid, density, method = c("pearson", "kendall", "spearman"))
# 2. stop("'x' must be numeric")

# %%
boxplot(volatile.acidity,critic.acid)
title("volatile.acidity vs. critic.acid")
# Out:
# Plot with title “volatile.acidity vs. critic.acid”

# %%
boxplot(chlorides~pH,data=wine, main="Box Plot",
   xlab="chlorides", ylab="pH")
# Out:
# Plot with title “Box Plot”
